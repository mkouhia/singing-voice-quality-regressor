# %%
import pandas as pd

audio_summary = pd.read_parquet("../data/etl_audio_summary.parquet")
segment_summary = pd.read_parquet("../data/etl_segment_summary.parquet")

# %%
with pd.option_context("display.max_colwidth", None):
    display(audio_summary[(audio_summary.message != "")][["tag", "message"]])
# Out:
#              tag  \
# 235  1U7A4ll_fdE
# 236  3eo6RirpUYw
# 237  230L9mf9BRY
# 238  DbLK7VJJKAU
# 239  VB8HpZ7Aw2E
# 240  4UJU9M-RMVo
# 241  1AChdBqEoUA
# 242  bIw-qj0g7xA
# 243  7bVDGLktPV8
# 244  hKYtaValuBs
# 245  _rGsUZoCpRg
# 246  i5oUu2-gSqU
# 247  eFTAKQOIGI8
# 248  jXME7QYsIUc
# 249  ktRX9S68luY
# 250  SPKLBPeHkR0
# 251  kG26Ym5VSAs
# 252  tOOJaeRJk8Q
# 253  r56FcMSJqkQ
# 254  umxF9rh349k
# 255  wKqEXP0lRwQ
# 256  U98cWCUFi7I
# 257  z30mP-4Tn3s
# 258  zeABEL8Z-UU
# 259  wKF-6qtJqnY
#
#                                                                                                                                                message
# 235  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 236                                                                                                                ERROR: Video unavailable
# 237                                                                ERROR: Private video
# Sign in if you've been granted access to this video
# 238                                         ERROR: Video unavailable
# This video is no longer available due to a copyright claim by kt alpha
# 239  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 240  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 241                                                                                                                ERROR: Video unavailable
# 242  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 243                                                                ERROR: Private video
# Sign in if you've been granted access to this video
# 244  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 245  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 246                                                                                                                ERROR: Video unavailable
# 247                                                                ERROR: Private video
# Sign in if you've been granted access to this video
# 248  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 249                                                                ERROR: Private video
# Sign in if you've been granted access to this video
# 250  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 251  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 252                                                                                                                ERROR: Video unavailable
# 253  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 254  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 255                                                                ERROR: Private video
# Sign in if you've been granted access to this video
# 256                                                                            ERROR: This video is only available to Music Premium members
# 257                                                                                                                ERROR: Video unavailable
# 258  ERROR: Video unavailable
# This video is no longer available because the YouTube account associated with this video has been terminated.
# 259                  ERROR: Video unavailable
# This video contains content from WMG, who has blocked it in your country on copyright grounds

# %%
with pd.option_context("display.max_colwidth", None):
    display(segment_summary[(segment_summary.message != "")][["tag", "num", "message"]])
# Out:
# Empty DataFrame
# Columns: [tag, num, message]
# Index: []
